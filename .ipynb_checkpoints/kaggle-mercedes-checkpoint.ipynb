# %% [markdown]
# # Kaggle Mercedes Challenge

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import Dense, Activation, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn.feature_selection import mutual_info_regression
from scipy.stats import pearsonr
from sklearn import linear_model



# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### Data Import

# %%
train = pd.read_csv('./data/train.csv')
testing = pd.read_csv('./data/test.csv')

# %%
train.shape
# Out:
# (4209, 378)

# %%
testing.shape
# Out:
# (4209, 377)

# %%
##extract testing IDs for later use
testing_ID = testing['ID']

# %% [markdown]
# ### Encode categorical variables and add features

# %%
##hack to prevent sorting of columns during append.
testing.insert(1,'y','0')
testing['y'] = testing['y'].astype('float64')

## combine data for label encoding
all_data = train.append(testing,ignore_index=True)

# %%
## columns to encode
to_encode = ['X0','X1','X2','X3','X4','X5','X6','X8']
le = {}


for column in to_encode:
    le[column] = LabelEncoder()
    le[column].fit(all_data[column])
    all_data[column] = le[column].transform(all_data[column])

# %% [markdown]
# #### add features

# %%
##sum all apparent option columns to see if this is a valuable feature

cols_to_sum = all_data.columns.values
cols_to_sum = np.delete(cols_to_sum,list(range(0,10)))
all_data = all_data.assign(option_sum = all_data[cols_to_sum].sum(axis=1))

# %%
##Create empty column and extract index
all_data['option_sumb'] = 'NaN'
all_index = all_data.index.values

##Calculate decimal value for all binary columns
for idx in all_index:
    all_data['option_sumb'][idx] = all_data.loc[idx,'X10':'X384'].values.astype('int').dot(2**np.arange(367)[::-1])
    
##Categorize it to remove any bias based on the decimal value
le_sumb = LabelEncoder()
le_sumb.fit(all_data['option_sumb'])
all_data['option_sumb'] = le_sumb.transform(all_data['option_sumb'])
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# #### looking at gap in IDs

# %%
#all_data_ID = all_data['ID']
#shift_all_data_ID = all_data_ID.drop(all_data_ID.index[0],)

#shift_ID = pd.Series([8417])
#all_data['ID_gap'] = (shift_all_data_ID.append(shift_ID, ignore_index=True) - all_data_ID)

# %% [markdown]
# #### drop zero variance columns

# %%
##identify columns with 0 variance in train data
var_train = pd.DataFrame(train.var(),columns=['variance']).reset_index()
remove_train = var_train[var_train['variance']==0]['index'].as_matrix()

##identify columns with 0 variance in testing data
var_testing = pd.DataFrame(testing.var(),columns=['variance']).reset_index()
remove_testing = var_testing[var_testing['variance']==0]['index'].as_matrix()
##remove y from list
ind = np.argwhere(remove_testing=='y')
remove_testing = np.delete(remove_testing, ind)

##Drop columns with 0 variance in either train or test
all_data.drop(remove_train, axis=1, inplace=True)
all_data.drop(remove_testing, axis=1, inplace=True)

# %% [markdown]
# #### drop duplicate columns

# %%
all_data = all_data.T.drop_duplicates().T

# %% [markdown]
# #### complementary columns

# %%
all_columns = all_data.columns.values
to_drop = []

for col in all_columns:
    
    if col in to_drop:
        continue
        
    ind = np.argwhere(all_columns==col)
    compare_columns = np.delete(all_columns, ind)
    complimentary_columns = []
    
    for comp in compare_columns:
        
        uniq = all_data[[col,comp]].sum(axis=1).nunique()
    
        if uniq==1:
            complimentary_columns.append(comp)
            to_drop.append(comp)
    #print (col, complimentary_columns,sep=':')
           
  
all_data.drop(to_drop, axis=1, inplace=True)

# %% [markdown]
# #### remove high correlation variables

# %%
corr_threshold = .8

all_columns = all_data.columns.values
to_drop = []

for feat1 in all_columns:
    
    if feat1 in to_drop:
        continue
        
    ind = np.argwhere(all_columns==feat1)
    features_to_corr = np.delete(all_columns, ind)
    correlated_features = []
    
    for feat2 in features_to_corr:
        
        pcorr, pvalue = pearsonr(all_data[feat1], all_data[feat2] )
    
        if pcorr > corr_threshold:
            correlated_features.append(feat2)
            to_drop.append(feat2)
            pcorr2, pvalue2 = pearsonr(all_data[feat2], all_data['y'])
            print (pcorr2, pvalue2, sep=':')

    print (feat1, correlated_features, sep=':')
           
  
#all_data.drop(to_drop, axis=1, inplace=True)
# Out:
# ID:[]
# y:[]
# X0:[]
# X1:[]
# X2:[]
# X3:[]
# X4:[]
# X5:[]
# X6:[]
# X8:[]
# X10:[]
# X12:[]
# X13:[]
# 0.0190022156163:0.0812733173014
# 0.0244030823308:0.0251575171097
# X14:['X191', 'X251']
# -0.00840436251449:0.440709003787
# X15:['X260']
# X16:[]
# -0.0155417625123:0.153918640702
# X17:['X325']
# X18:[]
# -0.0386129152081:0.000394827681872
# X19:['X215']
# X20:[]
# X21:[]
# X22:[]
# X23:[]
# X24:[]
# X26:[]
# X27:[]
# -0.0131062550328:0.229221175196
# X28:['X148']
# -0.0377941189543:0.000523720010173
# -0.0321289676786:0.00319686930015
# -0.0252342513015:0.0205987736501
# -0.0397392763164:0.000265356950993
# -0.0379314157452:0.000499675531533
# -0.0384879040417:0.000412372764379
# -0.036718006455:0.000753045646236
# X29:['X54', 'X162', 'X166', 'X232', 'X272', 'X276', 'X328']
# X30:[]
# X31:[]
# X32:[]
# X33:[]
# X34:[]
# X36:[]
# X38:[]
# X40:[]
# X41:[]
# X42:[]
# X43:[]
# 0.0222621645436:0.0411023756531
# X44:['X317']
# 0.00675775175625:0.535299643038
# 0.00769786795748:0.480074750083
# 0.00797283747829:0.464529908793
# X45:['X161', 'X202', 'X247']
# X46:[]
# 0.0169068700741:0.120882497453
# X47:['X267']
# 0.0249253126011:0.0222013920674
# 0.0129456714736:0.234977508005
# 0.0176265244484:0.105853875361
# X48:['X66', 'X170', 'X198']
# -0.0175438032534:0.107502073942
# X49:['X129']
# X50:[]
# X51:[]
# X52:[]
# 0.0197813184867:0.0695489205828
# 0.0132641185501:0.223660850202
# X53:['X308', 'X370']
# X55:[]
# X56:[]
# X57:[]
# -0.00451309560533:0.678862680596
# X58:['X137']
# X59:[]
# -0.0107903293134:0.322227479002
# X60:['X248']
# -0.0217760253668:0.0457293358203
# X61:['X120']
# X62:[]
# -0.00342768793371:0.753184281359
# X63:['X379']
# X64:[]
# X65:[]
# X67:[]
# X68:[]
# X69:[]
# X70:[]
# 0.00365547368245:0.737368789137
# X71:['X241']
# X73:[]
# X74:[]
# X75:[]
# X77:[]
# X78:[]
# X79:[]
# -0.0237104208176:0.029599721865
# -0.0269452005842:0.0134248798503
# -0.0351223079368:0.00126866375617
# -0.0367421030633:0.000747021869566
# -0.0363682338641:0.00084571765325
# X80:['X98', 'X101', 'X128', 'X304', 'X348']
# X81:[]
# X82:[]
# X83:[]
# 0.0128925998185:0.236902242445
# -0.00237054360031:0.827846311552
# -0.0111439732708:0.30662206205
# X85:['X187', 'X194', 'X246']
# X86:[]
# X87:[]
# -0.0114343650752:0.294188429428
# -0.00891741410873:0.413320374543
# -0.0134538056556:0.217108034884
# -0.0121996493369:0.263059476013
# -0.0139151886515:0.201748437702
# -0.0114343650752:0.294188429428
# -0.0121996493369:0.263059476013
# -0.0155199061653:0.154498471288
# -0.00967632464984:0.374708370712
# X88:['X90', 'X94', 'X99', 'X122', 'X217', 'X242', 'X243', 'X249', 'X320']
# X89:[]
# X91:[]
# X92:[]
# X95:[]
# 0.0202255217372:0.0635107432671
# 0.0231007155125:0.0340523842897
# X96:['X150', 'X363']
# X97:[]
# X100:[]
# X103:[]
# X104:[]
# X105:[]
# X106:[]
# -0.0156566802213:0.150897145269
# X108:['X371']
# X109:[]
# X110:[]
# X111:[]
# 0.0253531303528:0.0200095091381
# X112:['X183']
# X114:[]
# X115:[]
# X116:[]
# X117:[]
# 0.0270252431842:0.0131514536381
# X118:['X311']
# X123:[]
# X124:[]
# X125:[]
# 0.034083553631:0.001762406397
# 0.0244732311791:0.0247416023249
# X126:['X179', 'X264']
# X127:[]
# X131:[]
# X132:[]
# X133:[]
# X135:[]
# X136:[]
# -0.000286113343987:0.979060404688
# X138:['X140']
# X139:[]
# X141:[]
# X142:[]
# X143:[]
# X144:[]
# X145:[]
# X151:[]
# X152:[]
# X153:[]
# -0.000846190558211:0.938125416518
# -0.0080855548869:0.458239507374
# X154:['X321', 'X374']
# 0.00994451687373:0.361614446555
# X155:['X219']
# X156:[]
# X158:[]
# X159:[]
# X160:[]
# X163:[]
# X164:[]
# X165:[]
# -0.00904333353371:0.406755634098
# X167:['X277']
# X168:[]
# X169:[]
# X171:[]
# X173:[]
# X174:[]
# X175:[]
# X176:[]
# X177:[]
# -0.0401154666448:0.000231851544975
# X178:['X250']
# X180:[]
# X181:[]
# X182:[]
# 0.00822688104699:0.450420476349
# X184:['X266']
# -0.0276106097371:0.0112971383171
# X185:['X378']
# -0.00256316580177:0.81410391332
# X186:['X362']
# 0.00613141693637:0.573790959612
# -0.000617726614834:0.954809828308
# X189:['X238', 'X265']
# X190:[]
# X192:[]
# X195:[]
# X196:[]
# X197:[]
# X200:[]
# X201:[]
# X203:[]
# X204:[]
# X206:[]
# X207:[]
# 0.0115447404301:0.289552419836
# X208:['X368']
# X209:[]
# X210:[]
# X211:[]
# X212:[]
# X218:[]
# X220:[]
# X221:[]
# X223:[]
# 0.0244030823308:0.0251575171097
# X224:['X251']
# X225:[]
# X228:[]
# X229:[]
# X230:[]
# X231:[]
# X234:[]
# 0.0104386776856:0.33824987844
# X236:['X339']
# X237:[]
# -0.00409521304066:0.707154674649
# X240:['X365']
# X245:[]
# X252:[]
# X255:[]
# X256:[]
# X259:[]
# 0.0584800910699:7.90310294862e-08
# X261:['X314']
# X269:[]
# X270:[]
# X271:[]
# X273:[]
# X274:[]
# X275:[]
# X278:[]
# X280:[]
# X281:[]
# X282:[]
# X283:[]
# X284:[]
# X285:[]
# X286:[]
# X287:[]
# X288:[]
# X291:[]
# X292:[]
# X294:[]
# X298:[]
# X300:[]
# X301:[]
# X305:[]
# X306:[]
# X307:[]
# X309:[]
# X310:[]
# X312:[]
# X313:[]
# X315:[]
# X316:[]
# X318:[]
# X319:[]
# X322:[]
# X323:[]
# X327:[]
# X329:[]
# 0.0178111085167:0.102248337124
# 0.0199699189852:0.0669299899406
# 0.0211219653754:0.0526401207556
# 0.0207431306961:0.0570278509034
# X331:['X346', 'X349', 'X352', 'X367']
# X332:[]
# 0.0103657696146:0.341634761832
# X333:['X373']
# X334:[]
# X335:[]
# X336:[]
# X337:[]
# X338:[]
# X340:[]
# X341:[]
# X342:[]
# 0.0312369893326:0.00415357001634
# X343:['X376']
# X344:[]
# X345:[]
# X350:[]
# X351:[]
# X353:[]
# X354:[]
# X355:[]
# 0.00769786795748:0.480074750083
# 0.00797283747829:0.464529908793
# X356:['X202', 'X247']
# X357:[]
# -0.00237054360031:0.827846311552
# -0.0111439732708:0.30662206205
# X358:['X194', 'X246']
# X359:[]
# X361:[]
# X366:[]
# X372:[]
# X375:[]
# X377:[]
# X380:[]
# X383:[]
# X384:[]
# option_sum:[]
# option_sumb:[]

# %% [markdown]
# #### scale data

# %%
##remove target
#all_data_Y = all_data['y']
#all_data_X = all_data.drop('y', axis=1)

#scaler = preprocessing.MinMaxScaler(feature_range=(0,1)).fit(all_data_X)
#Scaled = pd.DataFrame(scaler.transform(all_data_X),columns=list(all_data_X))


##readd target
#Scaled['y']= all_data_Y
#all_data = Scaled

# %% [markdown]
# #### resplit data

# %%
## resplit the data
train = all_data[0:4209]
testing = all_data[4209:].drop('y', axis=1)

## drop ID
#train.drop('ID', inplace=True, axis=1)
#testing.drop('ID', inplace=True, axis=1)

# %% [markdown]
# ### Correlation

# %%
def plot_corr(df,size=10):
    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
    plt.yticks(range(len(corr.columns)), corr.columns);

# %%
#plot_corr(train,size=150)

# %%
pcorr = pd.DataFrame()
for feat in train:
    pcorr[feat] = pearsonr(train[feat], train['y'] )

pcorr = pcorr.T
pcorr.columns = ['corr','pvalue']
pcorr['corr'] = abs(pcorr['corr'])
pcorr.sort_values('corr', inplace=True, ascending=False)

# %%
top_pcorr = pcorr[:100].index.values
##remove y from list
ind = np.argwhere(top_pcorr=='y')
top_pcorr = np.delete(top_pcorr, ind)

# %%
top_pcorr
# Out:
# array(['X314', 'X261', 'X127', 'X232', 'X29', 'X136', 'X54', 'X328',
#        'X276', 'X162', 'X272', 'X313', 'X166', 'X250', 'X178', 'X275',
#        'X118', 'X316', 'X378', 'X234', 'X28', 'X185', 'X348', 'X80', 'X51',
#        'X264', 'X126', 'X108', 'X286', 'X179', 'X128', 'X371', 'X304',
#        'X311', 'X159', 'X66', 'X111', 'X101', 'X198', 'X43', 'X251',
#        'X191', 'X48', 'X14', 'X0', 'X315', 'X148', 'X61', 'X306', 'X98',
#        'X120', 'X52', 'X224', 'X170', 'X274', 'X215', 'X223', 'X19',
#        'X187', 'X273', 'X156', 'X17', 'X300', 'X68', 'X71', 'X3', 'X256',
#        'X75', 'X325', 'X46', 'X180', 'X354', 'X155', 'X229', 'X228',
#        'option_sum', 'X301', 'X241', 'X355', 'X150', 'X189', 'X343',
#        'X115', 'X238', 'X96', 'X376', 'X169', 'X47', 'X132', 'X255', 'X85',
#        'X363', 'X151', 'X350', 'X208', 'X331', 'X368', 'X209', 'X367'], dtype=object)

# %% [markdown]
# ### Mutual information

# %%
#mtrain = train.drop('y', axis=1)
#minfo = mutual_info_regression(mtrain, train.y.values)

#minfoFrame = pd.DataFrame({'feature':list(mtrain), 'minfo':minfo})
#minfoSorted = minfoFrame.sort_values(by='minfo', ascending=False)
#minfoSorted

# %%
#m_top = minfoSorted.feature.values[:20]
#m_top_y = np.append(m_top,'y')
#testing = testing[m_top]
#train = train[m_top_y]

# %% [markdown]
# ### Split out validation data

# %%
##feature limiting based on various methods
#top_feat_y = np.append(top_feat,'y')
#testing = testing[top_feat]
#train = train[top_feat_y]

#top_pcorr_y = np.append(top_pcorr,'y')
#testing = testing[top_pcorr]
#train = train[top_pcorr_y]

# %%
##Dived up the data into training and validation sets

training, validation = train_test_split(train, test_size = 0.2,random_state=42)

training_Y = training['y']
training_X = training.drop('y', axis=1)

validation_Y = validation['y']
validation_X = validation.drop('y', axis=1)

# %% [markdown]
# ### XGBoost

# %%
##Create train and validate DMatrix
trainingXGB = xgb.DMatrix(training_X, label=training_Y)
validateXGB = xgb.DMatrix(validation_X)

# %% [markdown]
# ### Finding best hyperparameters

# %%
##Set up crossvalidation and build model to test.  
ind_params = {'nthread':3}
cv_params = {'max_depth':[2],
             'min_child_weight':[8],
             'gamma':[0],
             'subsample':[1],
             'colsample_bytree':[.9],
             'learning_rate':[.3], 
             'n_estimators':[26],
             'reg_alpha':[0]
              }
##Build optimized model with GridSearch
model_xgb = GridSearchCV(xgb.XGBRegressor(**ind_params), 
                         cv_params, 
                         cv=10, 
                         n_jobs=3,
                         verbose=100,
                         scoring='r2')

model_xgb.fit(training_X, training_Y)

best_params = model_xgb.best_params_
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to new file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5, score=0.445492, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5, score=0.329432, total=   0.3s
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5, score=0.531601, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5
# [Parallel(n_jobs=3)]: Done   1 tasks      | elapsed:    0.4s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done   2 tasks      | elapsed:    0.4s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# [Parallel(n_jobs=3)]: Done   3 tasks      | elapsed:    0.4s
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5, score=0.632472, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5, score=0.573129, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5, score=0.655714, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5
# [Parallel(n_jobs=3)]: Done   4 tasks      | elapsed:    0.7s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done   5 tasks      | elapsed:    0.7s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done   6 tasks      | elapsed:    0.8s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5, score=0.571243, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5, score=0.630170, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5, score=0.587219, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6
# [Parallel(n_jobs=3)]: Done   7 tasks      | elapsed:    1.0s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).[Parallel(n_jobs=3)]: Done   8 tasks      | elapsed:    1.0s
#
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done   9 tasks      | elapsed:    1.1s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.5, score=0.554690, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6, score=0.472366, total=   0.3s
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6, score=0.332891, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6
# [Parallel(n_jobs=3)]: Done  10 tasks      | elapsed:    1.3s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  11 tasks      | elapsed:    1.4s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  12 tasks      | elapsed:    1.4s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6, score=0.546859, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6, score=0.574571, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6, score=0.631484, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6
# [Parallel(n_jobs=3)]: Done  13 tasks      | elapsed:    1.6s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  14 tasks      | elapsed:    1.7s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  15 tasks      | elapsed:    1.7s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6, score=0.660328, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6, score=0.565765, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6, score=0.636618, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7
# [Parallel(n_jobs=3)]: Done  16 tasks      | elapsed:    1.9s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  17 tasks      | elapsed:    2.0s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  18 tasks      | elapsed:    2.0s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6, score=0.600497, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.6, score=0.566625, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7, score=0.478770, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7
# [Parallel(n_jobs=3)]: Done  19 tasks      | elapsed:    2.2s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).[Parallel(n_jobs=3)]: Done  20 tasks      | elapsed:    2.2s
#
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  21 tasks      | elapsed:    2.3s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7, score=0.542946, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7, score=0.329151, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7, score=0.639224, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7
# [Parallel(n_jobs=3)]: Done  22 tasks      | elapsed:    2.5s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  23 tasks      | elapsed:    2.5s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  24 tasks      | elapsed:    2.6s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7, score=0.566498, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7, score=0.666786, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7, score=0.568458, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7
# [Parallel(n_jobs=3)]: Done  25 tasks      | elapsed:    2.8s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  26 tasks      | elapsed:    2.8s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  27 tasks      | elapsed:    2.9s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7, score=0.635310, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7, score=0.600500, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.7, score=0.567905, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8
# [Parallel(n_jobs=3)]: Done  28 tasks      | elapsed:    3.0s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  29 tasks      | elapsed:    3.1s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  30 tasks      | elapsed:    3.2s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8, score=0.484366, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8, score=0.326993, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8, score=0.533600, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8
# [Parallel(n_jobs=3)]: Done  31 tasks      | elapsed:    3.3s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  32 tasks      | elapsed:    3.4s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  33 tasks      | elapsed:    3.4s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8, score=0.639290, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8, score=0.570962, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8, score=0.666071, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8
# [Parallel(n_jobs=3)]: Done  34 tasks      | elapsed:    3.6s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    3.7s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  36 tasks      | elapsed:    3.7s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8, score=0.567136, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8, score=0.637880, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8, score=0.605292, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [Parallel(n_jobs=3)]: Done  37 tasks      | elapsed:    3.9s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  38 tasks      | elapsed:    3.9s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).
# [Parallel(n_jobs=3)]: Done  39 tasks      | elapsed:    4.0s
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.8, score=0.562610, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.475325, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.329740, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# Pickling array (shape=(176,), dtype=object).[Parallel(n_jobs=3)]: Done  40 tasks      | elapsed:    4.2s
#
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  41 tasks      | elapsed:    4.2s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  42 tasks      | elapsed:    4.3s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.540320, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.643232, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.570560, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [Parallel(n_jobs=3)]: Done  43 tasks      | elapsed:    4.5s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    4.5s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  45 tasks      | elapsed:    4.6s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.667425, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.565907, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.640245, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [Parallel(n_jobs=3)]: Done  46 tasks      | elapsed:    4.8s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  47 tasks      | elapsed:    4.8s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  48 tasks      | elapsed:    4.9s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.606981, total=   0.3s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.568421, total=   0.3s
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.472854, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [Parallel(n_jobs=3)]: Done  49 tasks      | elapsed:    5.1s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  50 tasks      | elapsed:    5.1s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done  51 tasks      | elapsed:    5.1s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.324118, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.537325, total=   0.2s
# [CV]  colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.641093, total=   0.2s
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV] colsample_bytree=0.5, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [Parallel(n_jobs=3)]: Done  52 tasks      | elapsed:    5.4s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# ...
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done 339 tasks      | elapsed:   39.7s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).[Parallel(n_jobs=3)]: Done 340 tasks      | elapsed:   39.8s
#
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.478015, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.329019, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.537241, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [Parallel(n_jobs=3)]: Done 341 tasks      | elapsed:   40.0s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done 342 tasks      | elapsed:   40.1s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# [Parallel(n_jobs=3)]: Done 343 tasks      | elapsed:   40.1s
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.645878, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.666086, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.578586, total=   0.4s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [Parallel(n_jobs=3)]: Done 344 tasks      | elapsed:   40.4s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done 345 tasks      | elapsed:   40.4s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).[Parallel(n_jobs=3)]: Done 346 tasks      | elapsed:   40.5s
#
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.569681, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.639747, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.605846, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [Parallel(n_jobs=3)]: Done 347 tasks      | elapsed:   40.7s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done 348 tasks      | elapsed:   40.8s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done 349 tasks      | elapsed:   40.8s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=0.9, score=0.562852, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.477597, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.333535, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [Parallel(n_jobs=3)]: Done 350 tasks      | elapsed:   41.0s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done 351 tasks      | elapsed:   41.1s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).[Parallel(n_jobs=3)]: Done 352 tasks      | elapsed:   41.2s
#
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.539468, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.575103, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.647115, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [Parallel(n_jobs=3)]: Done 353 tasks      | elapsed:   41.4s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3030,), dtype=int64).
# Pickling array (shape=(337,), dtype=int64).
# [Parallel(n_jobs=3)]: Done 354 tasks      | elapsed:   41.5s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [Parallel(n_jobs=3)]: Done 355 tasks      | elapsed:   41.5s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.669659, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.637205, total=   0.3s
# [CV] colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.567548, total=   0.3s
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=int64).
# Memmaping (shape=(176, 3367), dtype=float64) to old file /var/folders/9y/mr4j1gvs6g13yg_rkls01fhh0000gn/T/joblib_memmaping_pool_7660_8244103208/7660-8276198624-ccb2bd62fe8a07ac9db6a8f68a644c45.pkl
# Pickling array (shape=(176,), dtype=object).
# Pickling array (shape=(3367,), dtype=float64).
# Pickling array (shape=(3367,), dtype=int64).
# Pickling array (shape=(3031,), dtype=int64).
# Pickling array (shape=(336,), dtype=int64).
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.604122, total=   0.3s
# [CV]  colsample_bytree=1, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=8, n_estimators=26, reg_alpha=0, subsample=1, score=0.563948, total=   0.2s
# [Parallel(n_jobs=3)]: Done 360 out of 360 | elapsed:   42.1s finished

# %%
#best_params['learning_rate'] = .01
best_params
# Out:
# {'colsample_bytree': 0.9,
#  'gamma': 0,
#  'learning_rate': 0.01,
#  'max_depth': 2,
#  'min_child_weight': 8,
#  'n_estimators': 696,
#  'reg_alpha': 0,
#  'subsample': 1}

# %%
#best_params = {'colsample_bytree': 0.9,
 'gamma': 0,
 'learning_rate': 0.01,
 'max_depth': 2,
 'min_child_weight': 8,
 'n_estimators': 696,
 'reg_alpha': 0,
 'subsample': 1}

# %% [markdown]
# Looking for best number of rounds

# %%
##Tune booster rounds

cvresult = xgb.cv(best_params, 
                  trainingXGB, 
                  nfold=10,  
                  num_boost_round=10000, 
                  early_stopping_rounds=50,
                  metrics='rmse',
                  verbose_eval=True)




best_params['n_estimators'] = len(cvresult)
# Out:
# [0]	train-rmse:99.9866+0.0948955	test-rmse:99.983+0.85586
# [1]	train-rmse:98.9967+0.0942835	test-rmse:98.9929+0.855544
# [2]	train-rmse:98.0167+0.0936648	test-rmse:98.0135+0.854902
# [3]	train-rmse:97.0466+0.0929517	test-rmse:97.0436+0.85382
# [4]	train-rmse:96.0861+0.092235	test-rmse:96.0832+0.853425
# [5]	train-rmse:95.1354+0.0915114	test-rmse:95.1331+0.852583
# [6]	train-rmse:94.1946+0.0910869	test-rmse:94.1917+0.852485
# [7]	train-rmse:93.2631+0.0904713	test-rmse:93.2601+0.852096
# [8]	train-rmse:92.3409+0.0898765	test-rmse:92.3379+0.852312
# [9]	train-rmse:91.428+0.0895315	test-rmse:91.4249+0.852183
# [10]	train-rmse:90.5243+0.0888865	test-rmse:90.5212+0.852445
# [11]	train-rmse:89.6301+0.0876661	test-rmse:89.6265+0.853686
# [12]	train-rmse:88.7445+0.0870171	test-rmse:88.7417+0.8533
# [13]	train-rmse:87.8677+0.086417	test-rmse:87.8655+0.853106
# [14]	train-rmse:86.9998+0.0861127	test-rmse:86.9973+0.852924
# [15]	train-rmse:86.1406+0.0856898	test-rmse:86.1378+0.852801
# [16]	train-rmse:85.2899+0.0855187	test-rmse:85.2873+0.852558
# [17]	train-rmse:84.4479+0.0849484	test-rmse:84.4457+0.852724
# [18]	train-rmse:83.6147+0.0844922	test-rmse:83.6123+0.852909
# [19]	train-rmse:82.7897+0.0838975	test-rmse:82.7876+0.853057
# [20]	train-rmse:81.9731+0.0834668	test-rmse:81.9709+0.85354
# [21]	train-rmse:81.1647+0.0830259	test-rmse:81.1625+0.853659
# [22]	train-rmse:80.3643+0.0825278	test-rmse:80.3618+0.854363
# [23]	train-rmse:79.5722+0.0821066	test-rmse:79.5693+0.855009
# [24]	train-rmse:78.7884+0.0819414	test-rmse:78.7862+0.855027
# [25]	train-rmse:78.0122+0.0815273	test-rmse:78.0096+0.855658
# [26]	train-rmse:77.2438+0.0810432	test-rmse:77.2415+0.856148
# [27]	train-rmse:76.4832+0.0806236	test-rmse:76.4807+0.856751
# [28]	train-rmse:75.7305+0.0803569	test-rmse:75.7283+0.857852
# [29]	train-rmse:74.9855+0.0802563	test-rmse:74.9839+0.85785
# [30]	train-rmse:74.2477+0.0798055	test-rmse:74.2459+0.858832
# [31]	train-rmse:73.5173+0.0794679	test-rmse:73.5153+0.859908
# [32]	train-rmse:72.7946+0.0792926	test-rmse:72.7929+0.859893
# [33]	train-rmse:72.0791+0.0789399	test-rmse:72.0774+0.861036
# [34]	train-rmse:71.3708+0.0786059	test-rmse:71.3692+0.862093
# [35]	train-rmse:70.6698+0.0782867	test-rmse:70.6681+0.863337
# [36]	train-rmse:69.9758+0.0779857	test-rmse:69.9736+0.864422
# [37]	train-rmse:69.2888+0.0776822	test-rmse:69.2867+0.865558
# [38]	train-rmse:68.6087+0.077301	test-rmse:68.6071+0.866836
# [39]	train-rmse:67.9356+0.0770267	test-rmse:67.9336+0.867927
# [40]	train-rmse:67.2693+0.0767372	test-rmse:67.2669+0.869023
# [41]	train-rmse:66.6097+0.0766896	test-rmse:66.6073+0.870209
# [42]	train-rmse:65.9568+0.0763405	test-rmse:65.9538+0.871088
# [43]	train-rmse:65.3106+0.0761028	test-rmse:65.3076+0.872516
# [44]	train-rmse:64.6708+0.0758324	test-rmse:64.6678+0.873658
# [45]	train-rmse:64.0378+0.0756808	test-rmse:64.035+0.874983
# [46]	train-rmse:63.4111+0.0754527	test-rmse:63.4082+0.87647
# [47]	train-rmse:62.7906+0.0754051	test-rmse:62.7877+0.877788
# [48]	train-rmse:62.1767+0.0753955	test-rmse:62.1733+0.878817
# [49]	train-rmse:61.569+0.07506	test-rmse:61.5656+0.880799
# [50]	train-rmse:60.9674+0.074926	test-rmse:60.964+0.882578
# [51]	train-rmse:60.3717+0.0750258	test-rmse:60.3682+0.883893
# [52]	train-rmse:59.7824+0.0748548	test-rmse:59.7788+0.885585
# [53]	train-rmse:59.1989+0.0746771	test-rmse:59.1949+0.887166
# [54]	train-rmse:58.6216+0.0745031	test-rmse:58.6174+0.888985
# [55]	train-rmse:58.0501+0.0743514	test-rmse:58.0456+0.890697
# [56]	train-rmse:57.4843+0.0744448	test-rmse:57.4798+0.892683
# [57]	train-rmse:56.9242+0.0742393	test-rmse:56.9194+0.894342
# [58]	train-rmse:56.3701+0.0741026	test-rmse:56.3653+0.896201
# [59]	train-rmse:55.8216+0.0739707	test-rmse:55.8164+0.898261
# [60]	train-rmse:55.2786+0.073771	test-rmse:55.2733+0.900088
# [61]	train-rmse:54.7413+0.0736763	test-rmse:54.7361+0.901934
# [62]	train-rmse:54.2092+0.0735057	test-rmse:54.2039+0.903893
# [63]	train-rmse:53.6825+0.0732647	test-rmse:53.6775+0.905988
# [64]	train-rmse:53.1613+0.0734283	test-rmse:53.1565+0.907993
# [65]	train-rmse:52.6457+0.0733635	test-rmse:52.6408+0.910425
# [66]	train-rmse:52.1352+0.0732711	test-rmse:52.13+0.912546
# [67]	train-rmse:51.6301+0.0732247	test-rmse:51.6248+0.915005
# [68]	train-rmse:51.13+0.0731626	test-rmse:51.1244+0.917472
# [69]	train-rmse:50.6352+0.0731345	test-rmse:50.6295+0.919815
# [70]	train-rmse:50.1453+0.0732982	test-rmse:50.1398+0.921836
# [71]	train-rmse:49.6605+0.0732797	test-rmse:49.6549+0.923941
# [72]	train-rmse:49.1806+0.073279	test-rmse:49.1746+0.926433
# [73]	train-rmse:48.7058+0.073277	test-rmse:48.6997+0.928814
# [74]	train-rmse:48.2359+0.0732952	test-rmse:48.2298+0.931557
# [75]	train-rmse:47.7708+0.0733395	test-rmse:47.7647+0.933945
# [76]	train-rmse:47.3104+0.073352	test-rmse:47.3039+0.936521
# [77]	train-rmse:46.855+0.0733533	test-rmse:46.849+0.939323
# [78]	train-rmse:46.4043+0.0735399	test-rmse:46.3979+0.941649
# [79]	train-rmse:45.9582+0.0736024	test-rmse:45.9513+0.944193
# [80]	train-rmse:45.5166+0.0735936	test-rmse:45.5097+0.946892
# [81]	train-rmse:45.0795+0.073572	test-rmse:45.0728+0.949674
# [82]	train-rmse:44.647+0.0736874	test-rmse:44.6401+0.952256
# [83]	train-rmse:44.2189+0.0737053	test-rmse:44.212+0.954973
# [84]	train-rmse:43.7953+0.0737618	test-rmse:43.7883+0.957855
# [85]	train-rmse:43.3762+0.0738067	test-rmse:43.3687+0.960638
# [86]	train-rmse:42.9614+0.0739183	test-rmse:42.9538+0.9637
# [87]	train-rmse:42.5508+0.0740298	test-rmse:42.5434+0.966846
# [88]	train-rmse:42.1446+0.0741518	test-rmse:42.1369+0.969697
# [89]	train-rmse:41.7426+0.0742808	test-rmse:41.7348+0.972912
# [90]	train-rmse:41.3448+0.0744194	test-rmse:41.3368+0.97584
# [91]	train-rmse:40.9511+0.0744741	test-rmse:40.9432+0.978722
# [92]	train-rmse:40.5613+0.07454	test-rmse:40.5533+0.981787
# [93]	train-rmse:40.1758+0.0747248	test-rmse:40.1676+0.984926
# [94]	train-rmse:39.7943+0.0749202	test-rmse:39.7859+0.988027
# [95]	train-rmse:39.4168+0.0749023	test-rmse:39.4089+0.99136
# [96]	train-rmse:39.0431+0.0751252	test-rmse:39.0348+0.994459
# [97]	train-rmse:38.6733+0.07556	test-rmse:38.6651+0.997779
# [98]	train-rmse:38.3075+0.0757172	test-rmse:38.299+1.00068
# [99]	train-rmse:37.9456+0.0759226	test-rmse:37.9371+1.0042
# [100]	train-rmse:37.5874+0.0763989	test-rmse:37.5783+1.00756
# [101]	train-rmse:37.2331+0.0766407	test-rmse:37.2241+1.0109
# [102]	train-rmse:36.8825+0.0767905	test-rmse:36.8731+1.01426
# [103]	train-rmse:36.5354+0.0769551	test-rmse:36.5261+1.01787
# [104]	train-rmse:36.1919+0.0772357	test-rmse:36.1822+1.02143
# [105]	train-rmse:35.8523+0.0774853	test-rmse:35.8426+1.02501
# [106]	train-rmse:35.5162+0.0777594	test-rmse:35.5061+1.02848
# [107]	train-rmse:35.1837+0.0780149	test-rmse:35.1736+1.03226
# [108]	train-rmse:34.8548+0.0783258	test-rmse:34.8443+1.03564
# [109]	train-rmse:34.5291+0.078889	test-rmse:34.5186+1.03926
# [110]	train-rmse:34.2071+0.0791621	test-rmse:34.1962+1.04307
# [111]	train-rmse:33.8884+0.0793699	test-rmse:33.8772+1.04703
# [112]	train-rmse:33.5732+0.0796803	test-rmse:33.5618+1.05085
# [113]	train-rmse:33.2612+0.0799549	test-rmse:33.2494+1.05487
# [114]	train-rmse:32.9526+0.0802811	test-rmse:32.9405+1.05861
# [115]	train-rmse:32.6473+0.0805301	test-rmse:32.6352+1.0623
# [116]	train-rmse:32.3453+0.0808598	test-rmse:32.3326+1.06617
# [117]	train-rmse:32.0466+0.0812044	test-rmse:32.0338+1.07033
# [118]	train-rmse:31.7509+0.0815234	test-rmse:31.738+1.07435
# [119]	train-rmse:31.4585+0.0818825	test-rmse:31.4452+1.07825
# [120]	train-rmse:31.1691+0.0822633	test-rmse:31.1554+1.08218
# [121]	train-rmse:30.8827+0.0824357	test-rmse:30.8686+1.08629
# [122]	train-rmse:30.5994+0.0830375	test-rmse:30.5852+1.09046
# [123]	train-rmse:30.3192+0.0833709	test-rmse:30.3049+1.09464
# [124]	train-rmse:30.042+0.0837379	test-rmse:30.0273+1.09887
# [125]	train-rmse:29.7678+0.0840914	test-rmse:29.7532+1.10297
# [126]	train-rmse:29.4967+0.0844225	test-rmse:29.4818+1.10742
# [127]	train-rmse:29.228+0.0849866	test-rmse:29.2131+1.1114
# [128]	train-rmse:28.9624+0.0852769	test-rmse:28.9472+1.11568
# [129]	train-rmse:28.6996+0.0857954	test-rmse:28.684+1.11987
# [130]	train-rmse:28.4394+0.0862478	test-rmse:28.4238+1.12413
# [131]	train-rmse:28.1821+0.0867989	test-rmse:28.1661+1.12824
# [132]	train-rmse:27.9276+0.0871282	test-rmse:27.911+1.13258
# [133]	train-rmse:27.6757+0.087627	test-rmse:27.6588+1.13679
# [134]	train-rmse:27.4268+0.0881771	test-rmse:27.4095+1.14106
# [135]	train-rmse:27.1804+0.0886949	test-rmse:27.1629+1.14531
# [136]	train-rmse:26.9368+0.0892094	test-rmse:26.9186+1.1498
# [137]	train-rmse:26.6959+0.0897499	test-rmse:26.6773+1.15425
# [138]	train-rmse:26.4578+0.0901589	test-rmse:26.4389+1.15876
# [139]	train-rmse:26.2222+0.090362	test-rmse:26.203+1.16353
# [140]	train-rmse:25.9892+0.0909539	test-rmse:25.9694+1.16807
# [141]	train-rmse:25.7588+0.0915591	test-rmse:25.7386+1.17266
# [142]	train-rmse:25.5309+0.0921629	test-rmse:25.5101+1.17729
# [143]	train-rmse:25.3057+0.0928593	test-rmse:25.2845+1.18165
# [144]	train-rmse:25.0829+0.0934085	test-rmse:25.0614+1.18627
# [145]	train-rmse:24.8625+0.0940365	test-rmse:24.8406+1.19094
# [146]	train-rmse:24.6447+0.0945962	test-rmse:24.6224+1.19556
# [147]	train-rmse:24.4292+0.0951638	test-rmse:24.4065+1.2003
# [148]	train-rmse:24.2164+0.0954841	test-rmse:24.193+1.20528
# [149]	train-rmse:24.0059+0.0961917	test-rmse:23.9821+1.20993
# [150]	train-rmse:23.7977+0.0968219	test-rmse:23.7735+1.21468
# [151]	train-rmse:23.5918+0.0974544	test-rmse:23.5672+1.21939
# [152]	train-rmse:23.3882+0.0980854	test-rmse:23.3636+1.22425
# [153]	train-rmse:23.1871+0.0987729	test-rmse:23.1622+1.22884
# [154]	train-rmse:22.9881+0.0991628	test-rmse:22.9628+1.23406
# [155]	train-rmse:22.7913+0.0998152	test-rmse:22.7654+1.23888
# [156]	train-rmse:22.5969+0.100453	test-rmse:22.5701+1.24368
# [157]	train-rmse:22.4047+0.101159	test-rmse:22.3775+1.24841
# [158]	train-rmse:22.2146+0.101829	test-rmse:22.1868+1.2533
# [159]	train-rmse:22.0267+0.102527	test-rmse:21.9985+1.25831
# [160]	train-rmse:21.8409+0.103207	test-rmse:21.8123+1.26326
# [161]	train-rmse:21.6572+0.103886	test-rmse:21.6283+1.26829
# [162]	train-rmse:21.4759+0.104611	test-rmse:21.4462+1.27333
# [163]	train-rmse:21.2964+0.105425	test-rmse:21.2664+1.27824
# [164]	train-rmse:21.119+0.106249	test-rmse:21.0886+1.28312
# [165]	train-rmse:20.9437+0.107067	test-rmse:20.9127+1.28812
# [166]	train-rmse:20.7705+0.10778	test-rmse:20.7388+1.29335
# [167]	train-rmse:20.5992+0.10845	test-rmse:20.5667+1.29875
# [168]	train-rmse:20.43+0.109349	test-rmse:20.397+1.30362
# [169]	train-rmse:20.2631+0.110024	test-rmse:20.2296+1.30872
# [170]	train-rmse:20.098+0.110723	test-rmse:20.0641+1.31413
# [171]	train-rmse:19.9347+0.111474	test-rmse:19.9002+1.31931
# [172]	train-rmse:19.7732+0.112171	test-rmse:19.7379+1.32468
# [173]	train-rmse:19.6137+0.112862	test-rmse:19.5776+1.33019
# [174]	train-rmse:19.4561+0.113572	test-rmse:19.4189+1.33581
# [175]	train-rmse:19.3004+0.114406	test-rmse:19.2626+1.34118
# [176]	train-rmse:19.1465+0.115262	test-rmse:19.1078+1.34649
# [177]	train-rmse:18.9944+0.116004	test-rmse:18.9549+1.35185
# [178]	train-rmse:18.8442+0.116719	test-rmse:18.8038+1.35752
# [179]	train-rmse:18.6957+0.117517	test-rmse:18.6542+1.3629
# [180]	train-rmse:18.549+0.118354	test-rmse:18.5068+1.36839
# [181]	train-rmse:18.404+0.11919	test-rmse:18.3612+1.3738
# [182]	train-rmse:18.2608+0.12003	test-rmse:18.2175+1.37874
# [183]	train-rmse:18.1192+0.120773	test-rmse:18.0751+1.38439
# [184]	train-rmse:17.9795+0.12162	test-rmse:17.9349+1.38964
# [185]	train-rmse:17.8415+0.122522	test-rmse:17.796+1.39504
# [186]	train-rmse:17.7052+0.123375	test-rmse:17.6592+1.4002
# [187]	train-rmse:17.5707+0.124293	test-rmse:17.5243+1.40498
# [188]	train-rmse:17.4378+0.124959	test-rmse:17.3909+1.4109
# [189]	train-rmse:17.3066+0.125855	test-rmse:17.2593+1.41604
# [190]	train-rmse:17.1769+0.126643	test-rmse:17.1289+1.42153
# [191]	train-rmse:17.0491+0.127615	test-rmse:17.0008+1.42647
# [192]	train-rmse:16.9226+0.128501	test-rmse:16.8737+1.43191
# [193]	train-rmse:16.7976+0.129368	test-rmse:16.7484+1.43693
# [194]	train-rmse:16.6745+0.13033	test-rmse:16.6249+1.44187
# [195]	train-rmse:16.5528+0.131191	test-rmse:16.5027+1.44709
# [196]	train-rmse:16.4325+0.132072	test-rmse:16.3817+1.45231
# [197]	train-rmse:16.3138+0.132993	test-rmse:16.2624+1.45747
# [198]	train-rmse:16.1967+0.133914	test-rmse:16.1452+1.46247
# [199]	train-rmse:16.0809+0.134641	test-rmse:16.029+1.46843
# [200]	train-rmse:15.9668+0.135538	test-rmse:15.9144+1.47335
# [201]	train-rmse:15.8539+0.136385	test-rmse:15.801+1.47863
# [202]	train-rmse:15.7426+0.137299	test-rmse:15.6891+1.48353
# [203]	train-rmse:15.6328+0.138015	test-rmse:15.5785+1.48876
# [204]	train-rmse:15.5243+0.138682	test-rmse:15.469+1.49403
# [205]	train-rmse:15.4172+0.139607	test-rmse:15.3617+1.49877
# [206]	train-rmse:15.3116+0.140494	test-rmse:15.2554+1.50419
# [207]	train-rmse:15.2073+0.141252	test-rmse:15.1502+1.50896
# [208]	train-rmse:15.1041+0.14206	test-rmse:15.0464+1.51428
# [209]	train-rmse:15.0026+0.142811	test-rmse:14.9447+1.51895
# [210]	train-rmse:14.9022+0.143793	test-rmse:14.8439+1.52397
# [211]	train-rmse:14.8033+0.144521	test-rmse:14.7441+1.52867
# [212]	train-rmse:14.7055+0.145381	test-rmse:14.645+1.53398
# [213]	train-rmse:14.6092+0.146102	test-rmse:14.5481+1.53876
# [214]	train-rmse:14.514+0.146988	test-rmse:14.4521+1.54371
# [215]	train-rmse:14.4201+0.147835	test-rmse:14.3575+1.54869
# [216]	train-rmse:14.3275+0.148511	test-rmse:14.2639+1.55345
# [217]	train-rmse:14.236+0.149413	test-rmse:14.172+1.55821
# [218]	train-rmse:14.1458+0.150231	test-rmse:14.0806+1.56316
# [219]	train-rmse:14.057+0.151149	test-rmse:13.9912+1.56766
# [220]	train-rmse:13.9694+0.151875	test-rmse:13.9027+1.57249
# [221]	train-rmse:13.8827+0.152751	test-rmse:13.8152+1.57747
# [222]	train-rmse:13.7974+0.153527	test-rmse:13.7291+1.58195
# [223]	train-rmse:13.7132+0.15441	test-rmse:13.6442+1.58689
# [224]	train-rmse:13.6301+0.155179	test-rmse:13.5602+1.59136
# [225]	train-rmse:13.5483+0.155938	test-rmse:13.4776+1.59606
# [226]	train-rmse:13.4674+0.15664	test-rmse:13.396+1.6008
# [227]	train-rmse:13.3877+0.157509	test-rmse:13.3154+1.6057
# [228]	train-rmse:13.3092+0.158292	test-rmse:13.2364+1.61026
# [229]	train-rmse:13.2318+0.159006	test-rmse:13.158+1.61457
# [230]	train-rmse:13.1553+0.159816	test-rmse:13.0805+1.61926
# [231]	train-rmse:13.0801+0.160641	test-rmse:13.0045+1.62383
# [232]	train-rmse:13.0059+0.16136	test-rmse:12.9296+1.6285
# [233]	train-rmse:12.9325+0.16211	test-rmse:12.8556+1.63286
# [234]	train-rmse:12.8604+0.162926	test-rmse:12.7825+1.63751
# [235]	train-rmse:12.7893+0.163644	test-rmse:12.7104+1.64157
# [236]	train-rmse:12.7191+0.164525	test-rmse:12.6399+1.6458
# [237]	train-rmse:12.6497+0.165184	test-rmse:12.5694+1.65013
# [238]	train-rmse:12.5816+0.16588	test-rmse:12.5005+1.65469
# [239]	train-rmse:12.5145+0.166642	test-rmse:12.4324+1.65888
# [240]	train-rmse:12.4482+0.167505	test-rmse:12.3653+1.66292
# [241]	train-rmse:12.3829+0.168222	test-rmse:12.2991+1.66706
# [242]	train-rmse:12.3186+0.169121	test-rmse:12.2344+1.67121
# [243]	train-rmse:12.2553+0.169841	test-rmse:12.1702+1.67518
# [244]	train-rmse:12.1927+0.170476	test-rmse:12.1064+1.67918
# [245]	train-rmse:12.1312+0.171365	test-rmse:12.044+1.68288
# [246]	train-rmse:12.0705+0.172081	test-rmse:11.9828+1.68689
# [247]	train-rmse:12.0106+0.172881	test-rmse:11.922+1.69099
# [248]	train-rmse:11.9517+0.1736	test-rmse:11.8623+1.6947
# [249]	train-rmse:11.8937+0.174253	test-rmse:11.8035+1.6991
# [250]	train-rmse:11.8366+0.174965	test-rmse:11.7458+1.7028
# [251]	train-rmse:11.7803+0.175661	test-rmse:11.6884+1.70628
# [252]	train-rmse:11.7249+0.176332	test-rmse:11.6323+1.70998
# [253]	train-rmse:11.6702+0.177133	test-rmse:11.5765+1.7139
# [254]	train-rmse:11.6163+0.177795	test-rmse:11.5217+1.71748
# [255]	train-rmse:11.5634+0.178499	test-rmse:11.4681+1.72101
# [256]	train-rmse:11.5112+0.179185	test-rmse:11.4153+1.72453
# [257]	train-rmse:11.4597+0.180009	test-rmse:11.3634+1.72785
# [258]	train-rmse:11.409+0.180603	test-rmse:11.3116+1.73134
# [259]	train-rmse:11.3592+0.181297	test-rmse:11.2611+1.73461
# [260]	train-rmse:11.3099+0.182068	test-rmse:11.211+1.73807
# [261]	train-rmse:11.2616+0.18271	test-rmse:11.1619+1.74166
# [262]	train-rmse:11.214+0.183364	test-rmse:11.1134+1.7446
# [263]	train-rmse:11.1671+0.183985	test-rmse:11.0658+1.74798
# [264]	train-rmse:11.121+0.184662	test-rmse:11.0192+1.75139
# [265]	train-rmse:11.0755+0.185274	test-rmse:10.9728+1.75453
# [266]	train-rmse:11.0307+0.186051	test-rmse:10.9273+1.75755
# [267]	train-rmse:10.9866+0.18681	test-rmse:10.8826+1.76067
# [268]	train-rmse:10.9433+0.187437	test-rmse:10.8386+1.7634
# [269]	train-rmse:10.9007+0.1882	test-rmse:10.7955+1.76635
# [270]	train-rmse:10.8586+0.188809	test-rmse:10.7528+1.76926
# [271]	train-rmse:10.8173+0.189369	test-rmse:10.7106+1.77227
# [272]	train-rmse:10.7767+0.18997	test-rmse:10.6696+1.77477
# [273]	train-rmse:10.7367+0.190563	test-rmse:10.6289+1.77789
# [274]	train-rmse:10.6972+0.191316	test-rmse:10.5888+1.78052
# [275]	train-rmse:10.6584+0.191881	test-rmse:10.5493+1.78334
# [276]	train-rmse:10.6202+0.192578	test-rmse:10.5107+1.78603
# [277]	train-rmse:10.5826+0.193116	test-rmse:10.4722+1.7885
# [278]	train-rmse:10.5457+0.193682	test-rmse:10.4348+1.79116
# [279]	train-rmse:10.5093+0.194232	test-rmse:10.3978+1.79366
# [280]	train-rmse:10.4734+0.194733	test-rmse:10.3615+1.79622
# [281]	train-rmse:10.4382+0.195448	test-rmse:10.3255+1.79869
# [282]	train-rmse:10.4035+0.195989	test-rmse:10.2905+1.8009
# [283]	train-rmse:10.3695+0.196536	test-rmse:10.2559+1.80326
# [284]	train-rmse:10.336+0.197061	test-rmse:10.2216+1.80558
# [285]	train-rmse:10.303+0.197704	test-rmse:10.1883+1.8079
# [286]	train-rmse:10.2706+0.198252	test-rmse:10.1554+1.80994
# [287]	train-rmse:10.2387+0.198896	test-rmse:10.123+1.81209
# [288]	train-rmse:10.2073+0.199355	test-rmse:10.091+1.81421
# [289]	train-rmse:10.1763+0.199984	test-rmse:10.0593+1.81632
# [290]	train-rmse:10.146+0.200481	test-rmse:10.0286+1.81843
# [291]	train-rmse:10.1161+0.200964	test-rmse:9.99818+1.82078
# [292]	train-rmse:10.0867+0.201425	test-rmse:9.96836+1.82252
# [293]	train-rmse:10.0579+0.201884	test-rmse:9.93878+1.82439
# [294]	train-rmse:10.0295+0.202347	test-rmse:9.91009+1.82629
# [295]	train-rmse:10.0016+0.202802	test-rmse:9.88199+1.82813
# [296]	train-rmse:9.97405+0.203345	test-rmse:9.85409+1.83003
# [297]	train-rmse:9.94709+0.203809	test-rmse:9.82663+1.83185
# [298]	train-rmse:9.92059+0.204408	test-rmse:9.80008+1.83345
# [299]	train-rmse:9.89449+0.204839	test-rmse:9.77349+1.83525
# [300]	train-rmse:9.86882+0.205275	test-rmse:9.74751+1.83689
# [301]	train-rmse:9.84354+0.205792	test-rmse:9.72169+1.8387
# [302]	train-rmse:9.81873+0.206218	test-rmse:9.69665+1.84027
# [303]	train-rmse:9.79436+0.206648	test-rmse:9.6719+1.84161
# [304]	train-rmse:9.7703+0.20706	test-rmse:9.64741+1.84318
# [305]	train-rmse:9.74676+0.207597	test-rmse:9.62381+1.8445
# [306]	train-rmse:9.72357+0.207998	test-rmse:9.60029+1.84563
# [307]	train-rmse:9.70079+0.208388	test-rmse:9.57734+1.84704
# [308]	train-rmse:9.67834+0.208814	test-rmse:9.55457+1.84877
# [309]	train-rmse:9.6564+0.209247	test-rmse:9.53283+1.84989
# [310]	train-rmse:9.63474+0.209622	test-rmse:9.51082+1.85111
# [311]	train-rmse:9.6135+0.210126	test-rmse:9.48921+1.85235
# [312]	train-rmse:9.5925+0.210568	test-rmse:9.46805+1.85358
# [313]	train-rmse:9.57197+0.210966	test-rmse:9.44752+1.85475
# [314]	train-rmse:9.55176+0.211305	test-rmse:9.42703+1.8557
# [315]	train-rmse:9.53199+0.211691	test-rmse:9.4072+1.85676
# [316]	train-rmse:9.51245+0.212166	test-rmse:9.38744+1.85776
# [317]	train-rmse:9.49329+0.212495	test-rmse:9.36802+1.85875
# [318]	train-rmse:9.47447+0.212941	test-rmse:9.34872+1.86004
# [319]	train-rmse:9.45605+0.21331	test-rmse:9.33034+1.86087
# [320]	train-rmse:9.43784+0.213672	test-rmse:9.31214+1.86164
# [321]	train-rmse:9.41999+0.214088	test-rmse:9.29401+1.86261
# [322]	train-rmse:9.40244+0.214427	test-rmse:9.27618+1.86343
# [323]	train-rmse:9.38519+0.21477	test-rmse:9.25873+1.86421
# [324]	train-rmse:9.3682+0.215038	test-rmse:9.24164+1.86488
# [325]	train-rmse:9.3515+0.215431	test-rmse:9.22484+1.86579
# [326]	train-rmse:9.33515+0.215766	test-rmse:9.20802+1.86669
# [327]	train-rmse:9.31902+0.216042	test-rmse:9.19188+1.86742
# [328]	train-rmse:9.30322+0.216421	test-rmse:9.17609+1.8682
# [329]	train-rmse:9.28774+0.216753	test-rmse:9.16047+1.86894
# [330]	train-rmse:9.27241+0.217095	test-rmse:9.1452+1.86962
# [331]	train-rmse:9.25742+0.217358	test-rmse:9.13007+1.87035
# [332]	train-rmse:9.24264+0.217641	test-rmse:9.11511+1.87098
# [333]	train-rmse:9.22822+0.217954	test-rmse:9.10057+1.87137
# [334]	train-rmse:9.21398+0.2183	test-rmse:9.08626+1.87204
# [335]	train-rmse:9.19997+0.218545	test-rmse:9.07214+1.87266
# [336]	train-rmse:9.18623+0.218824	test-rmse:9.05828+1.87313
# [337]	train-rmse:9.17278+0.219093	test-rmse:9.04468+1.87359
# [338]	train-rmse:9.15953+0.219351	test-rmse:9.03148+1.87407
# [339]	train-rmse:9.14648+0.219651	test-rmse:9.01827+1.87483
# [340]	train-rmse:9.13362+0.219903	test-rmse:9.00531+1.87546
# [341]	train-rmse:9.12106+0.220142	test-rmse:8.99258+1.87558
# [342]	train-rmse:9.10857+0.220389	test-rmse:8.98023+1.87625
# [343]	train-rmse:9.09646+0.220659	test-rmse:8.96797+1.8769
# [344]	train-rmse:9.08458+0.220905	test-rmse:8.95599+1.87733
# [345]	train-rmse:9.07284+0.221179	test-rmse:8.9442+1.87787
# [346]	train-rmse:9.06128+0.221413	test-rmse:8.93262+1.87815
# [347]	train-rmse:9.04995+0.22161	test-rmse:8.92123+1.8785
# [348]	train-rmse:9.03892+0.221902	test-rmse:8.90998+1.87908
# [349]	train-rmse:9.02784+0.222089	test-rmse:8.89882+1.87954
# [350]	train-rmse:9.01718+0.222307	test-rmse:8.88841+1.87958
# [351]	train-rmse:9.00661+0.22258	test-rmse:8.87773+1.87998
# [352]	train-rmse:8.99625+0.222755	test-rmse:8.86721+1.88031
# [353]	train-rmse:8.9861+0.222957	test-rmse:8.85691+1.88049
# [354]	train-rmse:8.97612+0.223156	test-rmse:8.84726+1.88057
# [355]	train-rmse:8.9664+0.223361	test-rmse:8.83757+1.88067
# [356]	train-rmse:8.95665+0.223559	test-rmse:8.82784+1.88102
# [357]	train-rmse:8.94714+0.223802	test-rmse:8.81831+1.88132
# [358]	train-rmse:8.93783+0.223973	test-rmse:8.80913+1.88151
# [359]	train-rmse:8.92868+0.224242	test-rmse:8.79996+1.88143
# [360]	train-rmse:8.9197+0.224413	test-rmse:8.79101+1.88157
# [361]	train-rmse:8.91084+0.224573	test-rmse:8.78232+1.88165
# [362]	train-rmse:8.90222+0.224861	test-rmse:8.77371+1.88161
# [363]	train-rmse:8.8936+0.224973	test-rmse:8.76508+1.88197
# [364]	train-rmse:8.88529+0.225151	test-rmse:8.75667+1.88189
# [365]	train-rmse:8.87714+0.225396	test-rmse:8.74877+1.88196
# [366]	train-rmse:8.86902+0.225531	test-rmse:8.74091+1.88198
# [367]	train-rmse:8.86095+0.225701	test-rmse:8.73271+1.88214
# [368]	train-rmse:8.85321+0.225852	test-rmse:8.72494+1.88226
# [369]	train-rmse:8.84551+0.226022	test-rmse:8.71761+1.88236
# [370]	train-rmse:8.8379+0.226265	test-rmse:8.71015+1.88203
# [371]	train-rmse:8.83054+0.226391	test-rmse:8.70255+1.88196
# [372]	train-rmse:8.82325+0.226516	test-rmse:8.69542+1.88198
# [373]	train-rmse:8.81604+0.226619	test-rmse:8.6883+1.88182
# [374]	train-rmse:8.80909+0.22687	test-rmse:8.68132+1.88174
# [375]	train-rmse:8.80215+0.227033	test-rmse:8.67482+1.88168
# [376]	train-rmse:8.79537+0.227186	test-rmse:8.66806+1.88154
# [377]	train-rmse:8.78874+0.227268	test-rmse:8.6616+1.88134
# [378]	train-rmse:8.78217+0.227422	test-rmse:8.65513+1.88147
# [379]	train-rmse:8.77575+0.227524	test-rmse:8.64874+1.88138
# [380]	train-rmse:8.76939+0.227651	test-rmse:8.64246+1.88152
# [381]	train-rmse:8.76313+0.22787	test-rmse:8.63647+1.88098
# [382]	train-rmse:8.75708+0.228	test-rmse:8.6305+1.88091
# [383]	train-rmse:8.751+0.228132	test-rmse:8.62445+1.88104
# [384]	train-rmse:8.74515+0.228223	test-rmse:8.61869+1.88078
# [385]	train-rmse:8.73937+0.228372	test-rmse:8.61325+1.88066
# [386]	train-rmse:8.73366+0.228455	test-rmse:8.60764+1.88059
# [387]	train-rmse:8.72807+0.228578	test-rmse:8.60214+1.88053
# [388]	train-rmse:8.72254+0.228718	test-rmse:8.59684+1.88054
# [389]	train-rmse:8.71721+0.228821	test-rmse:8.59177+1.88032
# [390]	train-rmse:8.71195+0.228896	test-rmse:8.58668+1.88008
# [391]	train-rmse:8.70677+0.229073	test-rmse:8.58161+1.88
# [392]	train-rmse:8.70163+0.229129	test-rmse:8.57659+1.88002
# [393]	train-rmse:8.69657+0.229239	test-rmse:8.5718+1.87966
# [394]	train-rmse:8.69166+0.229332	test-rmse:8.5669+1.87942
# [395]	train-rmse:8.68679+0.229443	test-rmse:8.5621+1.87946
# [396]	train-rmse:8.68196+0.229504	test-rmse:8.55766+1.87923
# [397]	train-rmse:8.67728+0.22965	test-rmse:8.55292+1.87917
# [398]	train-rmse:8.67264+0.22971	test-rmse:8.54852+1.87887
# [399]	train-rmse:8.66802+0.229891	test-rmse:8.5442+1.87833
# [400]	train-rmse:8.66364+0.229959	test-rmse:8.54016+1.8779
# [401]	train-rmse:8.65924+0.230041	test-rmse:8.53589+1.87786
# [402]	train-rmse:8.65492+0.230113	test-rmse:8.53176+1.87776
# [403]	train-rmse:8.65078+0.230224	test-rmse:8.52771+1.8777
# [404]	train-rmse:8.64656+0.230385	test-rmse:8.52362+1.87719
# [405]	train-rmse:8.64241+0.230425	test-rmse:8.51963+1.87687
# [406]	train-rmse:8.63842+0.230474	test-rmse:8.51598+1.87669
# [407]	train-rmse:8.63453+0.230588	test-rmse:8.51235+1.87644
# [408]	train-rmse:8.63062+0.230632	test-rmse:8.50867+1.87615
# [409]	train-rmse:8.62681+0.23073	test-rmse:8.50502+1.8761
# [410]	train-rmse:8.62306+0.230764	test-rmse:8.50146+1.87577
# [411]	train-rmse:8.61938+0.230853	test-rmse:8.49805+1.87538
# [412]	train-rmse:8.61577+0.230923	test-rmse:8.49466+1.87517
# [413]	train-rmse:8.61216+0.230953	test-rmse:8.49135+1.87501
# [414]	train-rmse:8.60869+0.231027	test-rmse:8.48814+1.87488
# [415]	train-rmse:8.60515+0.231145	test-rmse:8.48465+1.87447
# [416]	train-rmse:8.60181+0.231191	test-rmse:8.48154+1.87421
# [417]	train-rmse:8.59848+0.231244	test-rmse:8.47844+1.87378
# [418]	train-rmse:8.59528+0.231333	test-rmse:8.47546+1.87371
# [419]	train-rmse:8.59198+0.231376	test-rmse:8.4724+1.87358
# [420]	train-rmse:8.58882+0.231415	test-rmse:8.46938+1.87329
# [421]	train-rmse:8.58574+0.23147	test-rmse:8.46641+1.87298
# [422]	train-rmse:8.58261+0.231492	test-rmse:8.4635+1.87285
# [423]	train-rmse:8.57959+0.231553	test-rmse:8.46062+1.87264
# [424]	train-rmse:8.57659+0.231594	test-rmse:8.45802+1.87247
# [425]	train-rmse:8.57372+0.231723	test-rmse:8.45523+1.87205
# [426]	train-rmse:8.57081+0.231738	test-rmse:8.45254+1.87161
# [427]	train-rmse:8.56797+0.231752	test-rmse:8.44999+1.87124
# [428]	train-rmse:8.56527+0.231827	test-rmse:8.44745+1.87115
# [429]	train-rmse:8.56255+0.231868	test-rmse:8.44489+1.8709
# [430]	train-rmse:8.55988+0.231889	test-rmse:8.44248+1.87046
# [431]	train-rmse:8.55722+0.232002	test-rmse:8.43992+1.86997
# [432]	train-rmse:8.55463+0.232046	test-rmse:8.43762+1.86986
# [433]	train-rmse:8.5521+0.232082	test-rmse:8.43526+1.86964
# [434]	train-rmse:8.54958+0.232135	test-rmse:8.43299+1.86945
# [435]	train-rmse:8.54711+0.232154	test-rmse:8.43053+1.86895
# [436]	train-rmse:8.5447+0.232195	test-rmse:8.42838+1.86877
# [437]	train-rmse:8.5423+0.232312	test-rmse:8.42629+1.86827
# [438]	train-rmse:8.53997+0.232319	test-rmse:8.42413+1.86801
# [439]	train-rmse:8.53767+0.232345	test-rmse:8.42209+1.86754
# [440]	train-rmse:8.5354+0.232369	test-rmse:8.41994+1.86726
# [441]	train-rmse:8.53313+0.232385	test-rmse:8.41777+1.8671
# [442]	train-rmse:8.53085+0.232419	test-rmse:8.41586+1.86696
# [443]	train-rmse:8.52869+0.232431	test-rmse:8.41402+1.8666
# [444]	train-rmse:8.52656+0.23245	test-rmse:8.41207+1.8662
# [445]	train-rmse:8.52439+0.232533	test-rmse:8.41008+1.86573
# [446]	train-rmse:8.52232+0.232543	test-rmse:8.40849+1.86553
# [447]	train-rmse:8.52024+0.232536	test-rmse:8.40668+1.86527
# [448]	train-rmse:8.51827+0.232606	test-rmse:8.40496+1.86511
# [449]	train-rmse:8.51632+0.23263	test-rmse:8.40314+1.8647
# [450]	train-rmse:8.5144+0.23266	test-rmse:8.40147+1.86458
# [451]	train-rmse:8.51246+0.232651	test-rmse:8.39972+1.86428
# [452]	train-rmse:8.51056+0.232673	test-rmse:8.39811+1.86394
# [453]	train-rmse:8.50868+0.232692	test-rmse:8.39636+1.86375
# [454]	train-rmse:8.50686+0.232674	test-rmse:8.39481+1.86348
# [455]	train-rmse:8.50505+0.23269	test-rmse:8.39331+1.86324
# [456]	train-rmse:8.50324+0.232766	test-rmse:8.39184+1.86273
# [457]	train-rmse:8.50149+0.23282	test-rmse:8.39042+1.86251
# [458]	train-rmse:8.49976+0.232811	test-rmse:8.3889+1.8622
# [459]	train-rmse:8.49807+0.232827	test-rmse:8.38748+1.86208
# [460]	train-rmse:8.49638+0.232824	test-rmse:8.38597+1.86184
# [461]	train-rmse:8.49469+0.232889	test-rmse:8.38454+1.86129
# [462]	train-rmse:8.49307+0.232891	test-rmse:8.38307+1.86102
# [463]	train-rmse:8.49149+0.232886	test-rmse:8.38172+1.8607
# [464]	train-rmse:8.48988+0.232939	test-rmse:8.38045+1.86045
# [465]	train-rmse:8.48838+0.232943	test-rmse:8.37922+1.86007
# [466]	train-rmse:8.48685+0.232991	test-rmse:8.37789+1.85984
# [467]	train-rmse:8.48532+0.232982	test-rmse:8.3768+1.85978
# [468]	train-rmse:8.48381+0.233057	test-rmse:8.37541+1.85932
# [469]	train-rmse:8.48239+0.233064	test-rmse:8.3743+1.85885
# [470]	train-rmse:8.48095+0.233054	test-rmse:8.37331+1.85849
# [471]	train-rmse:8.47952+0.23309	test-rmse:8.37218+1.85823
# [472]	train-rmse:8.47808+0.233127	test-rmse:8.37118+1.85802
# [473]	train-rmse:8.4767+0.233157	test-rmse:8.3702+1.85785
# [474]	train-rmse:8.47531+0.233127	test-rmse:8.36922+1.85734
# [475]	train-rmse:8.47397+0.233136	test-rmse:8.3681+1.85704
# [476]	train-rmse:8.47263+0.233163	test-rmse:8.36701+1.85687
# [477]	train-rmse:8.47132+0.233209	test-rmse:8.36601+1.85656
# [478]	train-rmse:8.46996+0.233182	test-rmse:8.36497+1.85616
# [479]	train-rmse:8.46871+0.233216	test-rmse:8.36413+1.85595
# [480]	train-rmse:8.46748+0.233212	test-rmse:8.36324+1.85575
# [481]	train-rmse:8.46627+0.233258	test-rmse:8.36206+1.85552
# [482]	train-rmse:8.46509+0.23327	test-rmse:8.36122+1.85513
# [483]	train-rmse:8.46389+0.233333	test-rmse:8.36026+1.85471
# [484]	train-rmse:8.46265+0.233308	test-rmse:8.35949+1.85425
# [485]	train-rmse:8.46146+0.233328	test-rmse:8.35865+1.85406
# [486]	train-rmse:8.46035+0.233378	test-rmse:8.35775+1.85382
# [487]	train-rmse:8.45924+0.233371	test-rmse:8.35699+1.85357
# [488]	train-rmse:8.45806+0.233381	test-rmse:8.35618+1.85347
# [489]	train-rmse:8.45696+0.233417	test-rmse:8.35521+1.85333
# [490]	train-rmse:8.45589+0.233411	test-rmse:8.35437+1.85292
# [491]	train-rmse:8.45479+0.233471	test-rmse:8.35358+1.85244
# [492]	train-rmse:8.45373+0.233492	test-rmse:8.35295+1.85221
# [493]	train-rmse:8.45266+0.233461	test-rmse:8.35213+1.85204
# [494]	train-rmse:8.45166+0.233494	test-rmse:8.35134+1.85183
# [495]	train-rmse:8.4507+0.233499	test-rmse:8.35071+1.85158
# [496]	train-rmse:8.44966+0.233552	test-rmse:8.34986+1.85112
# [497]	train-rmse:8.44864+0.233579	test-rmse:8.34916+1.85089
# [498]	train-rmse:8.44764+0.233633	test-rmse:8.34867+1.85077
# [499]	train-rmse:8.44668+0.233657	test-rmse:8.34813+1.8506
# [500]	train-rmse:8.44577+0.233653	test-rmse:8.3475+1.85017
# [501]	train-rmse:8.4448+0.233693	test-rmse:8.34687+1.84977
# [502]	train-rmse:8.44387+0.233698	test-rmse:8.34647+1.84954
# [503]	train-rmse:8.44295+0.233733	test-rmse:8.34561+1.84922
# [504]	train-rmse:8.44199+0.233743	test-rmse:8.34507+1.84909
# [505]	train-rmse:8.44105+0.233724	test-rmse:8.34433+1.84881
# [506]	train-rmse:8.44021+0.23373	test-rmse:8.34382+1.84859
# [507]	train-rmse:8.43935+0.233757	test-rmse:8.3434+1.8483
# [508]	train-rmse:8.43849+0.23375	test-rmse:8.34291+1.84832
# [509]	train-rmse:8.43764+0.233774	test-rmse:8.34251+1.84807
# [510]	train-rmse:8.43678+0.233744	test-rmse:8.34206+1.84774
# [511]	train-rmse:8.43599+0.233795	test-rmse:8.3416+1.84761
# [512]	train-rmse:8.43516+0.233847	test-rmse:8.34087+1.84721
# [513]	train-rmse:8.43428+0.233834	test-rmse:8.34039+1.84707
# [514]	train-rmse:8.43345+0.233842	test-rmse:8.33998+1.84686
# [515]	train-rmse:8.43267+0.233872	test-rmse:8.33959+1.84672
# [516]	train-rmse:8.43193+0.233882	test-rmse:8.33909+1.84639
# [517]	train-rmse:8.43118+0.233865	test-rmse:8.3384+1.8462
# [518]	train-rmse:8.4304+0.233891	test-rmse:8.3381+1.84591
# [519]	train-rmse:8.42964+0.233876	test-rmse:8.3377+1.84568
# [520]	train-rmse:8.42882+0.233914	test-rmse:8.3374+1.84539
# [521]	train-rmse:8.42808+0.233954	test-rmse:8.33692+1.84514
# [522]	train-rmse:8.4274+0.233999	test-rmse:8.33654+1.84505
# [523]	train-rmse:8.42669+0.233979	test-rmse:8.33618+1.84487
# [524]	train-rmse:8.42598+0.234008	test-rmse:8.33578+1.84477
# [525]	train-rmse:8.42527+0.233996	test-rmse:8.33534+1.84446
# [526]	train-rmse:8.42454+0.234043	test-rmse:8.33488+1.84412
# [527]	train-rmse:8.42379+0.234003	test-rmse:8.33464+1.8439
# [528]	train-rmse:8.4231+0.233984	test-rmse:8.33442+1.84372
# [529]	train-rmse:8.4224+0.233998	test-rmse:8.33403+1.84359
# [530]	train-rmse:8.42177+0.23403	test-rmse:8.33363+1.84337
# [531]	train-rmse:8.42111+0.23399	test-rmse:8.33332+1.84305
# [532]	train-rmse:8.42042+0.234051	test-rmse:8.33308+1.84272
# [533]	train-rmse:8.41973+0.234045	test-rmse:8.33252+1.84257
# [534]	train-rmse:8.41912+0.23404	test-rmse:8.33221+1.84239
# [535]	train-rmse:8.41847+0.234047	test-rmse:8.33182+1.84236
# [536]	train-rmse:8.41787+0.234079	test-rmse:8.33169+1.8422
# [537]	train-rmse:8.41723+0.23407	test-rmse:8.33132+1.84206
# [538]	train-rmse:8.41654+0.234027	test-rmse:8.33099+1.84173
# [539]	train-rmse:8.41591+0.234002	test-rmse:8.33066+1.84163
# [540]	train-rmse:8.41537+0.233993	test-rmse:8.33033+1.84141
# [541]	train-rmse:8.41475+0.233971	test-rmse:8.33006+1.84112
# [542]	train-rmse:8.41417+0.233991	test-rmse:8.32989+1.8408
# [543]	train-rmse:8.41359+0.23396	test-rmse:8.32968+1.8406
# [544]	train-rmse:8.41293+0.233968	test-rmse:8.3293+1.8405
# [545]	train-rmse:8.41235+0.234	test-rmse:8.32907+1.84042
# [546]	train-rmse:8.4118+0.234034	test-rmse:8.32883+1.84034
# [547]	train-rmse:8.41115+0.234022	test-rmse:8.32852+1.84019
# [548]	train-rmse:8.4106+0.233994	test-rmse:8.32823+1.84
# [549]	train-rmse:8.41006+0.23396	test-rmse:8.32808+1.83972
# [550]	train-rmse:8.40954+0.233947	test-rmse:8.32789+1.83954
# [551]	train-rmse:8.40899+0.233961	test-rmse:8.32756+1.83944
# [552]	train-rmse:8.40843+0.233982	test-rmse:8.32758+1.83936
# [553]	train-rmse:8.40794+0.233962	test-rmse:8.32741+1.83912
# [554]	train-rmse:8.40732+0.233938	test-rmse:8.32729+1.83875
# [555]	train-rmse:8.40681+0.233973	test-rmse:8.32701+1.83872
# [556]	train-rmse:8.40626+0.233907	test-rmse:8.32668+1.83858
# [557]	train-rmse:8.40576+0.233881	test-rmse:8.32645+1.83831
# [558]	train-rmse:8.40522+0.233851	test-rmse:8.32632+1.83826
# [559]	train-rmse:8.40472+0.233859	test-rmse:8.32615+1.83812
# [560]	train-rmse:8.40419+0.233895	test-rmse:8.32598+1.83794
# [561]	train-rmse:8.40368+0.233834	test-rmse:8.32579+1.83773
# [562]	train-rmse:8.40321+0.233817	test-rmse:8.3257+1.83754
# [563]	train-rmse:8.40276+0.233848	test-rmse:8.32558+1.83748
# [564]	train-rmse:8.40225+0.233847	test-rmse:8.32544+1.83737
# [565]	train-rmse:8.40171+0.233878	test-rmse:8.32532+1.83737
# [566]	train-rmse:8.40127+0.233899	test-rmse:8.32501+1.83726
# [567]	train-rmse:8.40082+0.233873	test-rmse:8.32494+1.83698
# [568]	train-rmse:8.40038+0.233857	test-rmse:8.32465+1.83682
# [569]	train-rmse:8.39982+0.233809	test-rmse:8.32465+1.83661
# [570]	train-rmse:8.39932+0.233836	test-rmse:8.32441+1.83655
# [571]	train-rmse:8.39882+0.233829	test-rmse:8.32427+1.83651
# [572]	train-rmse:8.3984+0.233831	test-rmse:8.32406+1.8365
# [573]	train-rmse:8.39792+0.233832	test-rmse:8.32379+1.83629
# [574]	train-rmse:8.39751+0.233801	test-rmse:8.32371+1.83607
# [575]	train-rmse:8.39699+0.233748	test-rmse:8.3237+1.83597
# [576]	train-rmse:8.39655+0.233753	test-rmse:8.32346+1.83578
# [577]	train-rmse:8.39604+0.233728	test-rmse:8.32327+1.8356
# [578]	train-rmse:8.39566+0.233718	test-rmse:8.32314+1.83538
# [579]	train-rmse:8.39522+0.233753	test-rmse:8.32308+1.8353
# [580]	train-rmse:8.39477+0.233707	test-rmse:8.32291+1.83537
# [581]	train-rmse:8.39432+0.233673	test-rmse:8.32282+1.8352
# [582]	train-rmse:8.39391+0.233701	test-rmse:8.32273+1.83504
# [583]	train-rmse:8.39349+0.233696	test-rmse:8.32267+1.83493
# [584]	train-rmse:8.39309+0.233653	test-rmse:8.3226+1.83469
# [585]	train-rmse:8.3927+0.233666	test-rmse:8.32239+1.83461
# [586]	train-rmse:8.39219+0.233657	test-rmse:8.32207+1.83434
# [587]	train-rmse:8.39177+0.233637	test-rmse:8.32188+1.83414
# [588]	train-rmse:8.39132+0.233563	test-rmse:8.32176+1.83388
# [589]	train-rmse:8.39093+0.233561	test-rmse:8.32184+1.83373
# [590]	train-rmse:8.39055+0.233588	test-rmse:8.32167+1.83355
# [591]	train-rmse:8.39009+0.233591	test-rmse:8.32146+1.8335
# [592]	train-rmse:8.38958+0.233568	test-rmse:8.32147+1.83342
# [593]	train-rmse:8.38914+0.233578	test-rmse:8.32129+1.83329
# [594]	train-rmse:8.38878+0.233551	test-rmse:8.32129+1.83328
# [595]	train-rmse:8.38841+0.233538	test-rmse:8.3212+1.83311
# [596]	train-rmse:8.38799+0.233564	test-rmse:8.32118+1.83308
# [597]	train-rmse:8.38766+0.233546	test-rmse:8.32106+1.83288
# [598]	train-rmse:8.38727+0.233567	test-rmse:8.32105+1.83269
# [599]	train-rmse:8.38686+0.233538	test-rmse:8.32106+1.83268
# [600]	train-rmse:8.38644+0.233475	test-rmse:8.32099+1.83244
# [601]	train-rmse:8.38604+0.233455	test-rmse:8.32088+1.83243
# [602]	train-rmse:8.3857+0.233478	test-rmse:8.32073+1.83224
# [603]	train-rmse:8.38532+0.233491	test-rmse:8.32067+1.83228
# [604]	train-rmse:8.38497+0.233475	test-rmse:8.32067+1.8321
# [605]	train-rmse:8.38459+0.233462	test-rmse:8.32053+1.83203
# [606]	train-rmse:8.3842+0.233469	test-rmse:8.32062+1.83198
# [607]	train-rmse:8.38387+0.233454	test-rmse:8.32055+1.83176
# [608]	train-rmse:8.3835+0.23341	test-rmse:8.32037+1.8316
# [609]	train-rmse:8.38311+0.233376	test-rmse:8.32019+1.83151
# [610]	train-rmse:8.38265+0.233347	test-rmse:8.32016+1.83134
# [611]	train-rmse:8.38231+0.233377	test-rmse:8.32015+1.83132
# [612]	train-rmse:8.382+0.233379	test-rmse:8.32016+1.83121
# [613]	train-rmse:8.38169+0.233387	test-rmse:8.32017+1.83115
# [614]	train-rmse:8.38129+0.233358	test-rmse:8.32012+1.8311
# [615]	train-rmse:8.38099+0.233346	test-rmse:8.3201+1.83092
# [616]	train-rmse:8.38063+0.233342	test-rmse:8.32005+1.83081
# [617]	train-rmse:8.38031+0.233379	test-rmse:8.31984+1.83067
# [618]	train-rmse:8.37996+0.233375	test-rmse:8.31971+1.83053
# [619]	train-rmse:8.37964+0.233352	test-rmse:8.31959+1.83061
# [620]	train-rmse:8.37931+0.233327	test-rmse:8.31958+1.83045
# [621]	train-rmse:8.37902+0.233313	test-rmse:8.31956+1.83027
# [622]	train-rmse:8.37866+0.233321	test-rmse:8.31952+1.83017
# [623]	train-rmse:8.37833+0.233322	test-rmse:8.31942+1.8301
# [624]	train-rmse:8.37803+0.233355	test-rmse:8.31947+1.83016
# [625]	train-rmse:8.37768+0.233386	test-rmse:8.31943+1.83012
# [626]	train-rmse:8.3773+0.233343	test-rmse:8.31948+1.82992
# [627]	train-rmse:8.37696+0.233325	test-rmse:8.31942+1.82987
# [628]	train-rmse:8.37664+0.23331	test-rmse:8.31952+1.82983
# [629]	train-rmse:8.37631+0.233285	test-rmse:8.31949+1.82968
# [630]	train-rmse:8.376+0.233245	test-rmse:8.31939+1.82955
# [631]	train-rmse:8.37574+0.233266	test-rmse:8.31937+1.82945
# [632]	train-rmse:8.37531+0.233242	test-rmse:8.31933+1.82928
# [633]	train-rmse:8.37497+0.233221	test-rmse:8.31924+1.82925
# [634]	train-rmse:8.37472+0.233221	test-rmse:8.31909+1.82918
# [635]	train-rmse:8.37442+0.233213	test-rmse:8.31904+1.8291
# [636]	train-rmse:8.37408+0.233174	test-rmse:8.31907+1.82891
# [637]	train-rmse:8.37377+0.233202	test-rmse:8.31904+1.8289
# [638]	train-rmse:8.37346+0.233201	test-rmse:8.31905+1.82878
# [639]	train-rmse:8.37318+0.233185	test-rmse:8.31913+1.8288
# [640]	train-rmse:8.37287+0.233173	test-rmse:8.31913+1.82875
# [641]	train-rmse:8.37255+0.233189	test-rmse:8.31893+1.82889
# [642]	train-rmse:8.3722+0.23317	test-rmse:8.3189+1.82871
# [643]	train-rmse:8.37186+0.233198	test-rmse:8.31882+1.82857
# [644]	train-rmse:8.37157+0.233156	test-rmse:8.31886+1.82841
# [645]	train-rmse:8.37122+0.233117	test-rmse:8.31883+1.82831
# [646]	train-rmse:8.3709+0.23313	test-rmse:8.31888+1.82831
# [647]	train-rmse:8.37065+0.233128	test-rmse:8.31881+1.82843
# [648]	train-rmse:8.37036+0.233145	test-rmse:8.31876+1.82828
# [649]	train-rmse:8.37008+0.233137	test-rmse:8.31866+1.82829
# [650]	train-rmse:8.36982+0.233132	test-rmse:8.31856+1.82806
# [651]	train-rmse:8.36944+0.233096	test-rmse:8.3184+1.82795
# [652]	train-rmse:8.36916+0.233052	test-rmse:8.31844+1.82781
# [653]	train-rmse:8.36881+0.23301	test-rmse:8.3185+1.82784
# [654]	train-rmse:8.36853+0.233001	test-rmse:8.31859+1.82775
# [655]	train-rmse:8.36823+0.23302	test-rmse:8.31855+1.82775
# [656]	train-rmse:8.36796+0.233032	test-rmse:8.31852+1.82773
# [657]	train-rmse:8.36765+0.233018	test-rmse:8.31858+1.82771
# [658]	train-rmse:8.36741+0.233016	test-rmse:8.31852+1.82762
# [659]	train-rmse:8.36715+0.233012	test-rmse:8.31835+1.82754
# [660]	train-rmse:8.3668+0.233013	test-rmse:8.31831+1.8274
# [661]	train-rmse:8.36644+0.232948	test-rmse:8.31833+1.82747
# [662]	train-rmse:8.36612+0.232931	test-rmse:8.31838+1.82744
# [663]	train-rmse:8.36581+0.232941	test-rmse:8.31834+1.82738
# [664]	train-rmse:8.36542+0.232894	test-rmse:8.31837+1.82726
# [665]	train-rmse:8.36516+0.232889	test-rmse:8.31854+1.82725
# [666]	train-rmse:8.36492+0.232882	test-rmse:8.31855+1.82724
# [667]	train-rmse:8.36466+0.232855	test-rmse:8.31856+1.82711
# [668]	train-rmse:8.36434+0.232834	test-rmse:8.3185+1.82705
# [669]	train-rmse:8.364+0.232814	test-rmse:8.31842+1.82695
# [670]	train-rmse:8.36372+0.232818	test-rmse:8.31839+1.82689
# [671]	train-rmse:8.36345+0.232789	test-rmse:8.31829+1.82688
# [672]	train-rmse:8.36315+0.232749	test-rmse:8.31834+1.82684
# [673]	train-rmse:8.36284+0.232775	test-rmse:8.31836+1.82693
# [674]	train-rmse:8.36261+0.232802	test-rmse:8.31834+1.827
# [675]	train-rmse:8.36233+0.232767	test-rmse:8.31845+1.82707
# [676]	train-rmse:8.36202+0.2327	test-rmse:8.31853+1.8269
# [677]	train-rmse:8.36167+0.232646	test-rmse:8.31858+1.82679
# [678]	train-rmse:8.36131+0.232701	test-rmse:8.31842+1.82651
# [679]	train-rmse:8.361+0.232698	test-rmse:8.3185+1.82657
# [680]	train-rmse:8.36077+0.232705	test-rmse:8.31837+1.82659
# [681]	train-rmse:8.36048+0.232705	test-rmse:8.31839+1.82652
# [682]	train-rmse:8.36015+0.23269	test-rmse:8.31839+1.82651
# [683]	train-rmse:8.35985+0.232665	test-rmse:8.31842+1.82655
# [684]	train-rmse:8.35959+0.232665	test-rmse:8.31835+1.82649
# [685]	train-rmse:8.35937+0.232682	test-rmse:8.31837+1.82641
# [686]	train-rmse:8.35901+0.232633	test-rmse:8.31837+1.82627
# [687]	train-rmse:8.35878+0.232612	test-rmse:8.31833+1.82617
# [688]	train-rmse:8.35849+0.232626	test-rmse:8.31829+1.82609
# [689]	train-rmse:8.35824+0.232607	test-rmse:8.31843+1.82608
# [690]	train-rmse:8.35789+0.232566	test-rmse:8.31844+1.82607
# [691]	train-rmse:8.35749+0.232585	test-rmse:8.31846+1.82577
# [692]	train-rmse:8.35726+0.232567	test-rmse:8.31845+1.82573
# [693]	train-rmse:8.35696+0.232599	test-rmse:8.31832+1.82568
# [694]	train-rmse:8.35667+0.232566	test-rmse:8.31833+1.82566
# [695]	train-rmse:8.35647+0.232557	test-rmse:8.31825+1.82556
# [696]	train-rmse:8.35604+0.232513	test-rmse:8.31829+1.82548
# [697]	train-rmse:8.3558+0.232495	test-rmse:8.31837+1.82555
# [698]	train-rmse:8.35552+0.232476	test-rmse:8.31846+1.82547
# [699]	train-rmse:8.35524+0.232474	test-rmse:8.31862+1.82547
# [700]	train-rmse:8.35497+0.232435	test-rmse:8.31864+1.82538
# [701]	train-rmse:8.35466+0.232408	test-rmse:8.3188+1.82538
# [702]	train-rmse:8.35435+0.232386	test-rmse:8.31879+1.8253
# [703]	train-rmse:8.35407+0.232385	test-rmse:8.31878+1.82522
# [704]	train-rmse:8.3538+0.232343	test-rmse:8.31866+1.82524
# [705]	train-rmse:8.35358+0.232363	test-rmse:8.31859+1.82525
# [706]	train-rmse:8.35327+0.232312	test-rmse:8.31879+1.82512
# [707]	train-rmse:8.353+0.232345	test-rmse:8.31863+1.82493
# [708]	train-rmse:8.35269+0.232304	test-rmse:8.31872+1.8248
# [709]	train-rmse:8.35237+0.232285	test-rmse:8.31887+1.82485
# [710]	train-rmse:8.35203+0.232286	test-rmse:8.31891+1.8247
# [711]	train-rmse:8.35174+0.23227	test-rmse:8.31881+1.82459
# [712]	train-rmse:8.3515+0.232249	test-rmse:8.31876+1.82457
# [713]	train-rmse:8.35131+0.232239	test-rmse:8.31882+1.82463
# [714]	train-rmse:8.35105+0.232205	test-rmse:8.31879+1.8246
# [715]	train-rmse:8.35075+0.23215	test-rmse:8.31878+1.82451
# [716]	train-rmse:8.35044+0.232143	test-rmse:8.31883+1.82445
# [717]	train-rmse:8.35019+0.232132	test-rmse:8.31887+1.82438
# [718]	train-rmse:8.34992+0.232121	test-rmse:8.31888+1.82434
# [719]	train-rmse:8.34964+0.232099	test-rmse:8.31897+1.82436
# [720]	train-rmse:8.34941+0.232066	test-rmse:8.31906+1.82436
# [721]	train-rmse:8.34916+0.232084	test-rmse:8.31897+1.82431
# [722]	train-rmse:8.34885+0.232053	test-rmse:8.31887+1.82421
# [723]	train-rmse:8.34849+0.232046	test-rmse:8.31899+1.82424
# [724]	train-rmse:8.34823+0.232035	test-rmse:8.31902+1.82412
# [725]	train-rmse:8.348+0.232042	test-rmse:8.31897+1.82403
# [726]	train-rmse:8.3477+0.232023	test-rmse:8.31905+1.82404
# [727]	train-rmse:8.34744+0.231982	test-rmse:8.31907+1.82412
# [728]	train-rmse:8.3471+0.231927	test-rmse:8.31917+1.82395
# [729]	train-rmse:8.34682+0.231932	test-rmse:8.31911+1.82389
# [730]	train-rmse:8.34651+0.231906	test-rmse:8.31898+1.82401
# [731]	train-rmse:8.34623+0.231851	test-rmse:8.3191+1.82387
# [732]	train-rmse:8.3459+0.231884	test-rmse:8.31913+1.82385
# [733]	train-rmse:8.34567+0.231871	test-rmse:8.31918+1.82378
# [734]	train-rmse:8.34539+0.231836	test-rmse:8.31915+1.8238
# [735]	train-rmse:8.34513+0.231842	test-rmse:8.31907+1.82373
# [736]	train-rmse:8.34488+0.231824	test-rmse:8.31909+1.82369
# [737]	train-rmse:8.34458+0.231818	test-rmse:8.31917+1.82372
# [738]	train-rmse:8.34434+0.231828	test-rmse:8.3192+1.82389
# [739]	train-rmse:8.34405+0.231827	test-rmse:8.31935+1.82387
# [740]	train-rmse:8.3438+0.231789	test-rmse:8.31926+1.82378
# [741]	train-rmse:8.34356+0.231761	test-rmse:8.31932+1.82377
# [742]	train-rmse:8.34331+0.231817	test-rmse:8.31938+1.82377
# [743]	train-rmse:8.34301+0.231805	test-rmse:8.31936+1.82368
# [744]	train-rmse:8.34273+0.231835	test-rmse:8.3193+1.82343

# %% [markdown]
# #### model testing on validation data

# %%
model_xgb = xgb.train(best_params,trainingXGB, num_boost_round = best_params['n_estimators'])
predY_xgb = model_xgb.predict(validateXGB)

# %%
r2_score(validation_Y, predY_xgb)
# Out:
# 0.60625108125441485

# %%
residual = validation_Y-predY_xgb
plt.scatter(y=residual, x=predY_xgb)

# %%
feat_imp = model_xgb.get_score(importance_type='gain')
importance = pd.DataFrame.from_dict(feat_imp, orient='index')
importance.columns = ['importance']
importance.sort_values(by='importance', ascending=False, inplace=True)

top_feat = importance.index[:50]

# %%
fig, ax = plt.subplots(figsize=(25, 50))
xgb.plot_importance(model_xgb, ax=ax, importance_type='gain')

# %% [markdown]
# ###  neural network

# %%
rows, features = training_X.shape

model_nn = Sequential()
model_nn.add(Dense(features, input_dim=features, activation='relu', bias_initializer='RandomNormal'))
#model_nn.add(Dropout(.6,))
model_nn.add(Dense(50, activation='relu', bias_initializer='RandomNormal'))
#model_nn.add(Dropout(.6,))
model_nn.add(Dense(1, activation='linear', bias_initializer='RandomNormal'))

model_nn.compile(loss='mean_squared_logarithmic_error', optimizer='adam')

# %%
weight_file = 'bestweights'
callbacks = [EarlyStopping(monitor='val_loss',patience=20, verbose=0),
            ModelCheckpoint(weight_file, verbose=0, save_best_only=True)]
model_nn.fit(training_X, training_Y, epochs=100000, batch_size=32, validation_data=(validation_X, validation_Y), callbacks=callbacks)

# %% [markdown]
# #### Linear regression

# %%
training_Y = training['y']
training_X = training.drop('y',axis=1)

validation_Y = validation['y']
validation_X = validation.drop('y',axis=1)



model_lm = linear_model.Lasso(alpha=.01, normalize=True, fit_intercept=False, max_iter=100000)
model_lm.fit(training_X,training_Y)
# Out:
# Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#    normalize=True, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
predY_lm = model_lm.predict(validation_X)
r2_score(validation_Y, predY_lm)
# Out:
# 0.57691824507306277

# %% [markdown]
# ### Final and submission

# %%
train_Y = train['y']
train_X = train.drop('y',axis=1)

testing_final = testing.values

# %% [markdown]
# #### nerual net sub

# %%
rows, features = train_X.shape

model_nn_final = Sequential()
model_nn_final.add(Dense(features, input_dim=features, activation='relu', bias_initializer='RandomNormal'))
#model_nn_final.add(Dropout(.6,))
model_nn_final.add(Dense(50, activation='relu', bias_initializer='RandomNormal'))
model_nn_final.add(Dense(1, activation='linear', bias_initializer='RandomNormal'))

model_nn_final.compile(loss='mean_squared_error', optimizer='adam')

model_nn_final.load_weights(weight_file, by_name=False)

predY_nn_final = model_nn.predict(testing_final, batch_size=128)

# %%
submission_nn = pd.DataFrame()
submission_nn['ID'] = testing['ID']
submission_nn['y'] = predY_nn_final


sub_file_nn = 'submission-nn.csv'
submission_nn.to_csv(sub_file_nn, index=False)

# %% [markdown]
# #### xgboost sub

# %%
train_final_Y = train['y']
train_final_X = train.drop('y',axis=1)
#train_final_X = train[top10]
#testing_final = testing[top10]
testing_final = testing

trainXGB = xgb.DMatrix(train_final_X, label=train_final_Y)
testingXGB = xgb.DMatrix(testing_final)

model_xgb_final = xgb.train(best_params,trainXGB, num_boost_round = best_params['n_estimators'])

predY_xgb_final = model_xgb_final.predict(testingXGB)



submission_xgb = pd.DataFrame()
submission_xgb['ID'] = testing_ID
submission_xgb['y'] = predY_xgb_final


sub_file_xgb = 'submission-xgb.csv'
submission_xgb.to_csv(sub_file_xgb, index=False)
